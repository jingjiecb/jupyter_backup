# %%
print("hello, world!")
# Out:
# hello, world!

# %%
import os
os.system("echo 'hahahahaha \nhaha'> payload.txt")
os.system("ls")
os.system("cat payload.txt")
# Out:
# haha.ipynb
# payload.txt
# test.ipynb
# Untitled.ipynb
# hahahahaha
# haha
# 0

# %%
import requests
filename="a.jpg"
url="https://pics4.baidu.com/feed/86d6277f9e2f0708cfd632ba99492c90a801f234.jpeg?token=342c21921d3a80cc0173e483db8621c7"
with open(filename,'wb') as f:            
    imgC = requests.get(url).content
    f.write(imgC)

# %%
filename = "cy.html"
url="http://cy.5156edu.com/"
with open(filename, "wb") as f:
    html = requests.get(url).content
    html = html.decode("gbk")
    print(html)
    f.write(html)
# Out:
# <html>
# <head>
# <meta http-equiv="Content-Language" content="zh-cn">
# <meta http-equiv="Content-Type" content="text/html; charset=gb2312">
# <link rel="stylesheet" type="text/css" href="style.css">
# <meta name="Description" content="在线成语词典查询"/>
# <meta name="Keywords" content="在线成语词典,看图猜成语,成语字典,成语接龙,成语大全,四字成语" />
# <title>在线成语词典</title>
# </head>
# <body topmargin="2" leftmargin="0">
# <TABLE width=758 align=center border=0>
#   <TBODY>
#   <TR>
#     <TD><br>
#       <div align="center">
#       <TABLE cellSpacing=0 cellPadding=0 border="0" width="720">
#         <TBODY>
#         <TR>
#           <TD rowspan="2" width="200" id=13719>
# <p align=center><img border="0" src="/images/logo.jpg" width="184" height="52"></p>
#       	</TD>
#           <TD height=1 width="18"></TD><TD height=1 width="460">&nbsp;
# </TD><TD height=1 width="26"></TD></TR>
#         <TR>
#           <TD width="18"><IMG src="/images/rebig.gif"></TD>
# ...
